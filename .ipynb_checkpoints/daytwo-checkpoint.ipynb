# %% [markdown]
# ## day two: 1/2

# %%
import pandas

# %%
csvFile = pandas.read_csv('daytwo.csv', header=None)

# %%
csvFile.head()
# Out:
#                              0
# 0    15-16 f: ffffffffffffffhf
# 1              6-8 b: bbbnvbbb
# 2  6-10 z: zhzzzzfzzzzzzzzzpzz
# 3      9-13 s: dmssskssqsssssf
# 4               5-6 v: hvvgvrm

# %%
ugh = []

# %%
for a in range(0, len(csvFile)):
    ugh.append(csvFile[0][a])

# %%
ugh[0]
# Out:
# '15-16 f: ffffffffffffffhf'

# %%
ugh[0].split(' ')
# Out:
# ['15-16', 'f:', 'ffffffffffffffhf']

# %%
len(ugh)
# Out:
# 1000

# %%
total = []

# %%
for a in ugh:
    b = a.split(' ')
    for item in b:
        total.append(item)

# print(total)

# %%
len(total)
# Out:
# 3000

# %%
times = []

# %%
sam = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

# %%
a = range(0, 299, 3)

# %%
limits = []

# %%
for a in range(0, 3000, 3):
    limits.append(total[a])

# %%
# print(limits)

# %%
letter = []

# %%
for b in range(1, 3000, 3):
    letter.append(total[b])

# %%
password = []

# %%
for c in range(2, 3000, 3):
    password.append(total[c])

# %%
for x in range(0,len(letter)):
    letter[x] = letter[x].replace(':',' ')

# %%
letter[0].rstrip()
# Out:
# 'f'

# %%
for l in range(0,len(letter)):
    letter[l] = letter[l].rstrip()

# %%
# print(letter)

# %%
# print(password)

# %%
y = limits[0].split('-')

# %%
int(y[0]) <= password[0].count(letter[0]) and int(y[0]) >= password[0].count(letter[0])
# Out:
# True

# %%
results = []

# %%
password[0].count(letter[0])
# Out:
# 15

# %%
for a in range(0,len(password)):
    y = limits[a].split('-')
#     print(y)
#     print(letter[a])
#     print(password[a])
#     print(password[a].count(letter[a]))
#     print(int(y[0]) <= password[a].count(letter[a]))
#     print(int(y[1]) >= password[a].count(letter[a]))
#     print(int(y[0]) <= password[a].count(letter[a]) and int(y[1]) >= password[a].count(letter[a]))
    results.append(int(y[0]) <= password[a].count(letter[a]) and int(y[1]) >= password[a].count(letter[a]))
#     print(int(y[0]) <= password[a].count(letter[a]) and int(y[1]) <= password[a].count(letter[a]))
#     results.append(int(y[0]) <= password[a].count(letter[a]) and int(y[1]) <= password[a].count(letter[a]))

# %%
sum(results)
# Out:
# 393

# %% [markdown]
# ## day two: 2/2

# %%
y = limits[0].split('-')
print(y[0])
print(y[1])
# Out:
# 15
# 16

# %%
results2 = []

# %%
for a in range(0,len(password)):
    y = limits[a].split('-')
    print(limits[a])
    print(password[a])
    print(letter[a])
    print(y)
    print(password[a][int(y[0])-1])
    print(password[a][int(y[1])-1])
    if (password[a][int(y[0])-1] == letter[a]) is not (password[a][int(y[1])-1] == letter[a]) or (password[a][int(y[1])-1] == letter[a]) is not(password[a][int(y[0])-1] == letter[a]):
        dummy = True
    else:
        dummy = False
    results2.append(dummy)
# Out:
# 15-16
# ffffffffffffffhf
# f
# ['15', '16']
# h
# f
# 6-8
# bbbnvbbb
# b
# ['6', '8']
# b
# b
# 6-10
# zhzzzzfzzzzzzzzzpzz
# z
# ['6', '10']
# z
# z
# 9-13
# dmssskssqsssssf
# s
# ['9', '13']
# q
# s
# 5-6
# hvvgvrm
# v
# ['5', '6']
# v
# r
# 1-8
# sssssssssss
# s
# ['1', '8']
# s
# s
# 1-3
# kxxx
# x
# ['1', '3']
# k
# x
# 2-5
# cckgxcnswc
# c
# ['2', '5']
# c
# x
# 10-11
# rjjpwdzkfjj
# j
# ['10', '11']
# j
# j
# 8-11
# wkrtlrxcskjglb
# r
# ['8', '11']
# c
# j
# 3-6
# mqrnhllxx
# l
# ['3', '6']
# r
# l
# 5-6
# zzzzlg
# z
# ['5', '6']
# l
# g
# 12-13
# qkrqxtrtsfxpnxg
# x
# ['12', '13']
# p
# n
# 3-7
# tsbkkkk
# k
# ['3', '7']
# b
# k
# 4-11
# jjjrjjjjjjjjjjj
# j
# ['4', '11']
# r
# j
# 2-4
# ccccc
# c
# ['2', '4']
# c
# c
# 2-15
# hhkhhhhhhhhhhhth
# h
# ['2', '15']
# h
# t
# 7-8
# hgcjkxhkskk
# k
# ['7', '8']
# h
# k
# 3-10
# ksxgrkcwfsxrqs
# s
# ['3', '10']
# x
# s
# 10-14
# hblznxdzxzzzrz
# z
# ['10', '14']
# z
# z
# 5-8
# mknrjhzzrjzl
# z
# ['5', '8']
# j
# z
# 2-4
# vqvvjhl
# v
# ['2', '4']
# q
# v
# 3-5
# fvzqrq
# q
# ['3', '5']
# z
# r
# 9-13
# flfpkfvffdfcz
# f
# ['9', '13']
# f
# z
# 1-7
# tbbbbbxbbbbbzbbb
# b
# ['1', '7']
# t
# x
# 6-8
# ccchvccccccccvzt
# c
# ['6', '8']
# c
# c
# 4-5
# wwwqww
# w
# ['4', '5']
# q
# w
# 1-7
# ffffffqf
# f
# ['1', '7']
# f
# q
# 5-11
# mmtmpmkrgrsm
# m
# ['5', '11']
# p
# s
# 8-13
# wpggctlxlwqckcsjwsn
# j
# ['8', '13']
# x
# k
# 1-14
# wzzzzzzzzzzzzzz
# z
# ['1', '14']
# w
# z
# 4-6
# pqpppsfxchwk
# p
# ['4', '6']
# p
# s
# 10-11
# ddddddddvkdddd
# d
# ['10', '11']
# k
# d
# 3-7
# vfmhccvg
# v
# ['3', '7']
# m
# v
# 10-11
# jjjjjcjjjfrzt
# j
# ['10', '11']
# f
# r
# 4-6
# xkwzdxcvkr
# x
# ['4', '6']
# z
# x
# 1-3
# kkkkkkkk
# k
# ['1', '3']
# k
# k
# 1-7
# clllllzlllllll
# l
# ['1', '7']
# c
# z
# 4-6
# nnnfnn
# n
# ['4', '6']
# f
# n
# 14-15
# lfllllxllllllllllm
# l
# ['14', '15']
# l
# l
# 3-10
# ppvppppppppppppppppp
# p
# ['3', '10']
# v
# p
# 7-8
# blbllllf
# l
# ['7', '8']
# l
# f
# 2-6
# pppphmpppp
# p
# ['2', '6']
# p
# m
# 7-10
# ppmjczjvvj
# j
# ['7', '10']
# j
# j
# 1-9
# dgtstttltttttvt
# t
# ['1', '9']
# d
# t
# 10-16
# hkhwvvwztwwwwgdb
# w
# ['10', '16']
# w
# b
# 3-4
# wwwn
# w
# ['3', '4']
# w
# n
# 6-7
# xxxxxxt
# x
# ['6', '7']
# x
# t
# 9-10
# gzqcbbjrbqdz
# q
# ['9', '10']
# b
# q
# 9-17
# qtttttttttttttttwt
# t
# ['9', '17']
# t
# w
# 11-12
# phtzzhqztpzz
# z
# ['11', '12']
# z
# z
# 7-18
# sggggggggggggggggv
# g
# ['7', '18']
# g
# v
# 11-14
# nnnnnnnnnnnnnsn
# n
# ['11', '14']
# n
# s
# 8-11
# qbcqqqqqqqqq
# q
# ['8', '11']
# q
# q
# 1-6
# ktwtttt
# t
# ['1', '6']
# k
# t
# 14-16
# zzzzzzzzzzzzzmzzzz
# z
# ['14', '16']
# m
# z
# 5-6
# mmmmhcm
# m
# ['5', '6']
# h
# c
# 8-10
# dxcpbqzbxd
# z
# ['8', '10']
# b
# d
# 12-13
# pppppppptpppppppppp
# p
# ['12', '13']
# p
# p
# 16-17
# pgwplpwpbpnppwppdspp
# p
# ['16', '17']
# p
# d
# 8-11
# xzsdbgvssdp
# s
# ['8', '11']
# s
# p
# 12-13
# zknzkgjqhpxbk
# k
# ['12', '13']
# b
# k
# 3-5
# ccccvc
# c
# ['3', '5']
# c
# v
# 2-3
# vknsqwfcqgl
# f
# ['2', '3']
# k
# n
# 13-16
# lllllnkllslwhsll
# l
# ['13', '16']
# h
# l
# 2-4
# txcz
# z
# ['2', '4']
# x
# z
# 14-15
# kdhhshhdhphxjshh
# h
# ['14', '15']
# s
# h
# 10-14
# pxpvpkprpjppvpjw
# p
# ['10', '14']
# j
# p
# 5-8
# slqssjszsssssl
# s
# ['5', '8']
# s
# z
# 11-12
# wwwwwwwwwwdtw
# w
# ['11', '12']
# d
# t
# 2-3
# xwrn
# r
# ['2', '3']
# w
# r
# 15-18
# ddbdddddddddddzddxdd
# d
# ['15', '18']
# z
# x
# 15-16
# ttttttktttttdvtvtt
# t
# ['15', '16']
# t
# v
# 3-5
# kjwpll
# l
# ['3', '5']
# w
# l
# 13-14
# wvwwwwwwwwwtpl
# w
# ['13', '14']
# p
# l
# 2-5
# mmvmwbjmmmmmmmxmmmmm
# m
# ['2', '5']
# m
# w
# 3-4
# qbcxpx
# x
# ['3', '4']
# c
# x
# 4-5
# kkjwkkbjkkkpkffjpzk
# k
# ['4', '5']
# w
# k
# 14-16
# drrlgrznrwmrhrnr
# r
# ['14', '16']
# r
# r
# 8-14
# pppppppfpppppsp
# p
# ['8', '14']
# f
# s
# 15-19
# hrplhhqkhhxjshhjcxl
# h
# ['15', '19']
# h
# l
# 11-13
# cjjxxqzdcxwww
# z
# ['11', '13']
# w
# w
# 1-7
# zzzzzzhxzz
# z
# ['1', '7']
# z
# h
# 9-10
# mfnqtmjmfm
# m
# ['9', '10']
# f
# m
# 2-6
# xbnnksjqdtdg
# b
# ['2', '6']
# b
# s
# 6-8
# vwddsprkkptksckfzv
# k
# ['6', '8']
# p
# k
# 7-8
# cwlmsbxs
# b
# ['7', '8']
# x
# s
# 1-3
# hhkhh
# h
# ['1', '3']
# h
# k
# 8-12
# jtgwjztfjmbj
# j
# ['8', '12']
# f
# j
# 6-7
# vvvvblvhv
# v
# ['6', '7']
# l
# v
# 5-9
# rbwkwqctpvfw
# w
# ['5', '9']
# w
# p
# 2-4
# szss
# s
# ['2', '4']
# z
# s
# 6-8
# rqmkrnhb
# m
# ['6', '8']
# n
# b
# 9-14
# qqcqcnqbqkqqqfq
# q
# ['9', '14']
# q
# f
# 10-11
# qvrbvbvvvslhvvxvp
# v
# ['10', '11']
# s
# l
# 7-8
# kkkkkzfk
# k
# ['7', '8']
# f
# k
# 11-18
# vvvvvvvvvvvvvvvvvvv
# v
# ['11', '18']
# v
# v
# 10-12
# hsmzqgrzhvdhpvgnhh
# h
# ['10', '12']
# v
# h
# 3-4
# jtdcct
# t
# ['3', '4']
# d
# c
# 3-15
# glbccmxglvbvkzkh
# k
# ['3', '15']
# b
# k
# 4-5
# gmmhm
# m
# ['4', '5']
# h
# m
# 1-7
# zsssssssss
# s
# ['1', '7']
# z
# s
# 3-14
# hhhhhhhhhhpjhhhhb
# h
# ['3', '14']
# h
# h
# 8-17
# xxxxxxxxxxxxxmxxxxx
# x
# ['8', '17']
# x
# x
# 7-8
# nnnpcrnzf
# n
# ['7', '8']
# n
# z
# 6-12
# kkkktjkknqkk
# k
# ['6', '12']
# j
# k
# 5-8
# sxrrrrrsrh
# r
# ['5', '8']
# r
# s
# 8-9
# fcpvvvvvg
# v
# ['8', '9']
# v
# g
# 10-17
# hvzvvmvvvvfvvvvbj
# v
# ['10', '17']
# v
# j
# 6-9
# mbvnqwrlm
# m
# ['6', '9']
# w
# m
# 10-11
# kkkkkkfkshk
# k
# ['10', '11']
# h
# k
# 4-6
# nskwtwtwgw
# w
# ['4', '6']
# w
# w
# 1-4
# twdtgbtjbv
# t
# ['1', '4']
# t
# t
# 11-13
# bbbbbbbbbbbbtbbbb
# b
# ['11', '13']
# b
# t
# 3-6
# jjfjjjr
# j
# ['3', '6']
# f
# j
# 9-10
# wwnwwvwwvww
# w
# ['9', '10']
# v
# w
# 10-11
# fflfhkdtqhh
# h
# ['10', '11']
# h
# h
# 3-6
# jhzjdpbpjppx
# p
# ['3', '6']
# z
# p
# 16-18
# xxxxxxxxxxxxxxxxxxx
# x
# ['16', '18']
# x
# x
# 10-15
# ppppgpzhpppstpb
# p
# ['10', '15']
# p
# b
# 10-11
# qrrrjrlkzrx
# r
# ['10', '11']
# r
# x
# 8-12
# gggggggrgggjg
# g
# ['8', '12']
# r
# j
# 13-15
# czzzzzfzzbzzqzzz
# z
# ['13', '15']
# q
# z
# 7-17
# fffcffffffffffffjfff
# f
# ['7', '17']
# f
# j
# 4-7
# mtjjhsq
# j
# ['4', '7']
# j
# q
# 4-14
# mxsxmtggkwjhbc
# x
# ['4', '14']
# x
# c
# 10-11
# cccccccccsv
# c
# ['10', '11']
# s
# v
# 9-10
# hqkhwhhthb
# h
# ['9', '10']
# h
# b
# 7-8
# mjvjjhhj
# j
# ['7', '8']
# h
# j
# 11-15
# ffffffffffqffrvffff
# f
# ['11', '15']
# q
# v
# 6-11
# ztjdccccchct
# c
# ['6', '11']
# c
# c
# 1-12
# jqqgqqqnqqqqqqq
# q
# ['1', '12']
# j
# q
# 5-12
# gttnvnbfnzznrmx
# n
# ['5', '12']
# v
# n
# 1-8
# zbtxblcb
# b
# ['1', '8']
# z
# b
# 4-10
# tttvttnttt
# t
# ['4', '10']
# v
# t
# 4-17
# lzhpgxpfxgvsjnzxp
# p
# ['4', '17']
# p
# p
# 4-5
# dfbdd
# d
# ['4', '5']
# d
# d
# 5-15
# mmmmmmmmchmlpmpmmmmm
# m
# ['5', '15']
# m
# p
# 14-15
# dcddddddddddhddldd
# d
# ['14', '15']
# d
# d
# 3-14
# wwwsxwcwswwpgcmqnrws
# w
# ['3', '14']
# w
# c
# 2-9
# nnnnnznnwtnsndhx
# n
# ['2', '9']
# n
# w
# 1-3
# zzqzz
# z
# ['1', '3']
# z
# q
# 4-12
# ccclccccccccc
# c
# ['4', '12']
# l
# c
# 2-4
# rrpz
# r
# ['2', '4']
# r
# z
# 6-9
# mmhgkqbcj
# m
# ['6', '9']
# q
# j
# 3-4
# vgjqh
# r
# ['3', '4']
# j
# q
# 2-7
# hmpfdktscc
# m
# ['2', '7']
# m
# t
# 11-16
# xxpxxxjqxqxxxxxsx
# x
# ['11', '16']
# x
# s
# 6-8
# hvdhjhdf
# h
# ['6', '8']
# h
# f
# 1-2
# ngxgxhgc
# g
# ['1', '2']
# n
# g
# 1-2
# bjmbbjnkwnt
# b
# ['1', '2']
# b
# j
# 9-10
# qgqggggcgr
# g
# ['9', '10']
# g
# r
# 9-10
# rhzwpwrkbxg
# x
# ['9', '10']
# b
# x
# 9-11
# wzrmhmzzfskzqlbz
# z
# ['9', '11']
# f
# k
# 9-11
# bbbbbbmbszbbbxbbw
# b
# ['9', '11']
# s
# b
# 4-7
# njgcvvv
# g
# ['4', '7']
# c
# v
# 6-8
# sxtlwntvrlllp
# l
# ['6', '8']
# n
# v
# 3-4
# mrlvs
# m
# ['3', '4']
# l
# v
# 1-3
# xrrr
# r
# ['1', '3']
# x
# r
# 9-10
# vlvtxvvqvv
# v
# ['9', '10']
# v
# v
# 4-5
# kskjvsn
# j
# ['4', '5']
# j
# v
# 3-4
# sjjs
# s
# ['3', '4']
# j
# s
# 5-6
# lgwlll
# l
# ['5', '6']
# l
# l
# 2-3
# zqkhkq
# k
# ['2', '3']
# q
# k
# 5-10
# lxxwggkzxxqxx
# x
# ['5', '10']
# g
# x
# 10-16
# rrrrrrrrrrbrzrrr
# r
# ['10', '16']
# r
# r
# 13-14
# bbbbbbbbbbbbcb
# b
# ['13', '14']
# c
# b
# 4-5
# qbjbc
# c
# ['4', '5']
# b
# c
# 14-15
# lsvqdmnhnbnkrnhm
# n
# ['14', '15']
# n
# h
# 2-4
# lrjc
# c
# ['2', '4']
# r
# c
# 11-12
# clwwwwwwwwwcwmw
# w
# ['11', '12']
# w
# c
# 7-8
# vncgxkzbzgzbsxbzrz
# z
# ['7', '8']
# z
# b
# 5-7
# gwmwfcw
# w
# ['5', '7']
# f
# w
# 5-6
# wggkwccfwkcbn
# c
# ['5', '6']
# w
# c
# 5-6
# gggdbpbcmhvb
# b
# ['5', '6']
# b
# p
# 3-5
# nvtqtzttn
# t
# ['3', '5']
# t
# t
# 7-9
# rrrrrrvrrrr
# r
# ['7', '9']
# v
# r
# 1-4
# vnrrr
# r
# ['1', '4']
# v
# r
# 4-9
# klmmqxmnt
# m
# ['4', '9']
# m
# t
# 3-5
# rsnncnj
# n
# ['3', '5']
# n
# c
# 12-19
# rqbbbbbtbbbtbbbkbbh
# b
# ['12', '19']
# t
# h
# 18-19
# hqqzxqlkqfqqqqfbjsq
# q
# ['18', '19']
# s
# q
# 4-7
# nvgwcjqc
# w
# ['4', '7']
# w
# q
# 4-6
# trrpdv
# r
# ['4', '6']
# p
# v
# 10-14
# gcggggggggggwn
# g
# ['10', '14']
# g
# n
# 2-8
# hbgrdgglqqbj
# g
# ['2', '8']
# b
# l
# 4-5
# qqqqmr
# q
# ['4', '5']
# q
# m
# 3-4
# ntrxbcr
# x
# ['3', '4']
# r
# x
# 2-5
# pjgxcfczcc
# c
# ['2', '5']
# j
# c
# 8-11
# lgpwwptbtldb
# b
# ['8', '11']
# b
# d
# 9-12
# sssmwlsssssrssss
# s
# ['9', '12']
# s
# r
# 5-12
# rlwbzczmvrzzt
# z
# ['5', '12']
# z
# z
# 4-13
# mmmkmphjgmlcqb
# m
# ['4', '13']
# k
# q
# 9-10
# vqqglfpxll
# l
# ['9', '10']
# l
# l
# 5-8
# wktwjvzwwmwj
# w
# ['5', '8']
# j
# w
# 4-5
# hrfklcllpmhnpbcnl
# l
# ['4', '5']
# k
# l
# 6-10
# svdjtmdccm
# m
# ['6', '10']
# m
# m
# 12-13
# bbvdgcfsqtmgk
# k
# ['12', '13']
# g
# k
# 13-15
# rrvrrrrqrrrthrr
# r
# ['13', '15']
# h
# r
# 3-14
# grhzxvmhqhljwm
# h
# ['3', '14']
# h
# m
# 4-5
# kgpkc
# k
# ['4', '5']
# k
# c
# 1-8
# jqqqqqqqqqq
# q
# ['1', '8']
# j
# q
# 9-18
# gxwxwcxswwvbtxwkfw
# w
# ['9', '18']
# w
# w
# 7-10
# rgsnzzvcxg
# g
# ['7', '10']
# v
# g
# 4-14
# ztgldqllvrrbrkm
# l
# ['4', '14']
# l
# k
# 3-5
# tnrndnnn
# n
# ['3', '5']
# r
# d
# 3-9
# jmjjhjjbmjjvjjl
# j
# ['3', '9']
# j
# m
# 9-10
# sszbssmsssssfs
# s
# ['9', '10']
# s
# s
# 15-16
# jmjjjkjjjjjjjjcpjjj
# j
# ['15', '16']
# c
# p
# 7-10
# lljljlssls
# l
# ['7', '10']
# s
# s
# 2-3
# ntnn
# n
# ['2', '3']
# t
# n
# 6-7
# qmvmmjmrsm
# m
# ['6', '7']
# j
# m
# 13-20
# bbbkbbbbbbdbbbbbbwbb
# b
# ['13', '20']
# b
# b
# 11-14
# gwvzwwzwvxjzmw
# w
# ['11', '14']
# j
# w
# 13-15
# vsckdjqnsknkkkvhk
# k
# ['13', '15']
# k
# v
# 5-9
# drrprlfrn
# r
# ['5', '9']
# r
# n
# 10-11
# xxxxxxxxxfxxxxx
# x
# ['10', '11']
# f
# x
# 10-11
# lfnllfqxwzghblld
# l
# ['10', '11']
# z
# g
# 3-18
# rrnrrrrrrrrrrrrrrpr
# r
# ['3', '18']
# n
# p
# 4-7
# wmjtmgm
# m
# ['4', '7']
# t
# m
# 7-8
# zzzmzzfz
# z
# ['7', '8']
# f
# z
# 1-15
# djjjjjcjjjjqjjj
# j
# ['1', '15']
# d
# j
# 3-4
# bvcd
# d
# ['3', '4']
# c
# d
# 8-9
# rrrrxdrrrrrr
# r
# ['8', '9']
# r
# r
# 5-6
# jqszdfbmpfdhdclg
# f
# ['5', '6']
# d
# f
# 4-9
# lllmllllllll
# l
# ['4', '9']
# m
# l
# 12-16
# ttttttttttttttttt
# t
# ['12', '16']
# t
# t
# 10-11
# ddfddddddddfd
# d
# ['10', '11']
# d
# d
# 7-14
# hhrnwhhhklcjhhmts
# h
# ['7', '14']
# h
# h
# 5-7
# tqqqqqfqk
# q
# ['5', '7']
# q
# f
# 9-16
# ppppppppbpppppppp
# p
# ['9', '16']
# b
# p
# 3-5
# wqtgtpmmxffrqhmf
# r
# ['3', '5']
# t
# t
# 4-5
# bbbfcbbxzd
# b
# ['4', '5']
# f
# c
# 9-11
# bmqqcqnhqsq
# q
# ['9', '11']
# q
# q
# 1-8
# jtkwjlzwhjjnjqjrj
# j
# ['1', '8']
# j
# w
# 3-6
# xxkxxxjzxndxh
# x
# ['3', '6']
# k
# x
# 16-17
# llllllllzllllnlvllll
# l
# ['16', '17']
# v
# l
# 4-5
# bmsgphslr
# p
# ['4', '5']
# g
# p
# 4-6
# bbbsbbbb
# b
# ['4', '6']
# s
# b
# 13-18
# lllllllllllllllllvll
# l
# ['13', '18']
# l
# v
# 5-6
# fbpfjb
# f
# ['5', '6']
# j
# b
# 4-5
# cdczx
# c
# ['4', '5']
# z
# x
# 2-8
# pxcxdvgrqgdjnrk
# x
# ['2', '8']
# x
# r
# 13-14
# wwswwgwwwwwwwm
# w
# ['13', '14']
# w
# m
# 6-7
# nnnbndnn
# n
# ['6', '7']
# d
# n
# 4-5
# lsgghg
# g
# ['4', '5']
# g
# h
# 17-19
# dzlwgqngbnktvhqzpbd
# d
# ['17', '19']
# p
# d
# 1-4
# dtddd
# d
# ['1', '4']
# d
# d
# 6-9
# dddddhddddd
# d
# ['6', '9']
# h
# d
# 5-6
# wwwwwww
# w
# ['5', '6']
# w
# w
# 10-11
# xlmxlxxmtrx
# x
# ['10', '11']
# r
# x
# 15-16
# dgpkrcvddfbxdrvd
# d
# ['15', '16']
# v
# d
# 1-3
# ccdcc
# c
# ['1', '3']
# c
# d
# 2-3
# bjpjj
# j
# ['2', '3']
# j
# p
# 1-9
# nqqqqqqqqqqqqq
# q
# ['1', '9']
# n
# q
# 10-17
# ddddddddddddddddtd
# d
# ['10', '17']
# d
# t
# 7-11
# mggglgsggggggsg
# g
# ['7', '11']
# s
# g
# 2-5
# tztttdtmq
# t
# ['2', '5']
# z
# t
# 8-12
# vvvvvvvlvvvvvvvvv
# v
# ['8', '12']
# l
# v
# 2-7
# llqlllbll
# l
# ['2', '7']
# l
# b
# 6-7
# ggggggm
# g
# ['6', '7']
# g
# m
# 3-9
# kkktkknxwrkkkkmhn
# k
# ['3', '9']
# k
# w
# 8-9
# brmbbbqbjbm
# b
# ['8', '9']
# b
# j
# 3-7
# hwcjxlx
# w
# ['3', '7']
# c
# x
# 13-20
# mptqtnvjfftfnvczjdvn
# n
# ['13', '20']
# n
# n
# 12-13
# hhhhhhhhhhhhvwhthhhh
# h
# ['12', '13']
# h
# v
# 3-9
# gjqjjjjjjj
# j
# ['3', '9']
# q
# j
# 3-5
# wpppv
# p
# ['3', '5']
# p
# v
# 1-8
# nnnnnnnlnnnn
# n
# ['1', '8']
# n
# l
# 6-7
# hhwtthnth
# h
# ['6', '7']
# h
# n
# 4-7
# vlnhkwvrtxhlbj
# h
# ['4', '7']
# h
# v
# 11-13
# qqtpgqqqqqwqqq
# q
# ['11', '13']
# w
# q
# 6-7
# gkhgggl
# g
# ['6', '7']
# g
# l
# 1-16
# hghsthqhhchnjhvh
# h
# ['1', '16']
# h
# h
# 8-11
# qllfltlzjlxllwh
# l
# ['8', '11']
# z
# x
# 5-6
# bbbdtrb
# b
# ['5', '6']
# t
# r
# 2-7
# mmdmfptmmmbmz
# m
# ['2', '7']
# m
# t
# 8-10
# hhhhhxhhhshhhhhh
# h
# ['8', '10']
# h
# s
# 2-4
# cklbktfdfpz
# k
# ['2', '4']
# k
# b
# 2-6
# wqjlcfpdlmfjkgbjjb
# q
# ['2', '6']
# q
# f
# 1-3
# zggggg
# g
# ['1', '3']
# z
# g
# 4-8
# wqncxcqcwdqwcn
# c
# ['4', '8']
# c
# c
# 4-5
# nnnnln
# n
# ['4', '5']
# n
# l
# 2-3
# lmbdqjf
# m
# ['2', '3']
# m
# b
# 8-17
# tttjttttttttttttkttt
# t
# ['8', '17']
# t
# k
# 7-10
# lllwllpllllflpll
# l
# ['7', '10']
# p
# l
# 1-5
# sxxxxx
# x
# ['1', '5']
# s
# x
# 8-9
# dnxjktrqr
# r
# ['8', '9']
# q
# r
# 9-14
# fdhghhhqhhhghh
# h
# ['9', '14']
# h
# h
# 5-10
# gclxxxxfxntxjnthzrq
# x
# ['5', '10']
# x
# n
# 9-18
# jvvlxnzmcwwcpxxtxx
# x
# ['9', '18']
# c
# x
# 15-16
# lllllllllllllnvllll
# l
# ['15', '16']
# v
# l
# 5-11
# fksqqwvrbfq
# q
# ['5', '11']
# q
# q
# 4-8
# pppmbzspvwqbbppp
# p
# ['4', '8']
# m
# p
# 7-8
# tftttttr
# t
# ['7', '8']
# t
# r
# 9-12
# nfhkhpthkzzkljqhkznp
# k
# ['9', '12']
# k
# k
# 9-10
# nxbnztvzrz
# z
# ['9', '10']
# r
# z
# 12-15
# lllllllllllplllll
# l
# ['12', '15']
# p
# l
# 2-16
# jrmlrfclhhqvfvnpb
# r
# ['2', '16']
# r
# p
# 1-3
# zppgpppg
# p
# ['1', '3']
# z
# p
# 7-9
# ssssssszxsl
# s
# ['7', '9']
# s
# x
# 3-4
# wllh
# l
# ['3', '4']
# l
# h
# 12-13
# swrsbwrwrrckr
# r
# ['12', '13']
# k
# r
# 1-4
# mmmmmmmmm
# m
# ['1', '4']
# m
# m
# 3-12
# rrhrlrgrrrrrrqrrrvcd
# r
# ['3', '12']
# h
# r
# 6-12
# kcpvlkrlkkdkkk
# k
# ['6', '12']
# k
# k
# 7-19
# nnnnnnnnnmnnnnnnnfzk
# n
# ['7', '19']
# n
# z
# 1-5
# qqfbqkcsqqcx
# q
# ['1', '5']
# q
# q
# 2-5
# nsxss
# s
# ['2', '5']
# s
# s
# 10-12
# bcwbbdbbbbbjb
# b
# ['10', '12']
# b
# j
# 5-6
# gggggtg
# g
# ['5', '6']
# g
# t
# 2-3
# nxxrxvwkmjxnfqrztc
# x
# ['2', '3']
# x
# x
# 8-11
# zhkjfttnxttt
# t
# ['8', '11']
# n
# t
# 3-9
# nnnnnnnknnn
# n
# ['3', '9']
# n
# n
# 9-13
# nzvpcztgrkzzfzs
# z
# ['9', '13']
# r
# f
# 14-16
# jdddddmdldbddcdd
# d
# ['14', '16']
# c
# d
# 2-5
# djwtgg
# g
# ['2', '5']
# j
# g
# 2-3
# wgww
# w
# ['2', '3']
# g
# w
# 4-8
# vvvxvvfvjvjv
# v
# ['4', '8']
# x
# v
# 6-7
# hvvfdfd
# d
# ['6', '7']
# f
# d
# 1-5
# jhknz
# j
# ['1', '5']
# j
# z
# 8-10
# ddddddddddddd
# d
# ['8', '10']
# d
# d
# 10-11
# ppppdpppppw
# p
# ['10', '11']
# p
# w
# 1-9
# bbcbbwbtj
# b
# ['1', '9']
# b
# j
# 4-5
# qqqqq
# q
# ['4', '5']
# q
# q
# 2-3
# hhxjjj
# j
# ['2', '3']
# h
# x
# 16-18
# gglgggggggggggghgggg
# g
# ['16', '18']
# h
# g
# 14-15
# vvvvvvvvvvvvvvmvv
# v
# ['14', '15']
# v
# m
# 1-3
# mxxxx
# x
# ['1', '3']
# m
# x
# 3-4
# qsqq
# q
# ['3', '4']
# q
# q
# 4-10
# xldvlcdmrmf
# m
# ['4', '10']
# v
# m
# 2-3
# xxgx
# x
# ['2', '3']
# x
# g
# 3-4
# tgvdtllftmnw
# t
# ['3', '4']
# v
# d
# 4-5
# xrhkhphhq
# h
# ['4', '5']
# k
# h
# 7-10
# srhslnjjjjjtn
# j
# ['7', '10']
# j
# j
# 4-5
# vvvsv
# v
# ['4', '5']
# s
# v
# 9-14
# wgggcgjgggvgjg
# g
# ['9', '14']
# g
# g
# 1-5
# qwnwv
# w
# ['1', '5']
# q
# v
# 12-14
# ppppzpsppzpjvzp
# p
# ['12', '14']
# j
# z
# 13-14
# vxvtvvvcsrqgxp
# v
# ['13', '14']
# x
# p
# 1-6
# kmskxk
# k
# ['1', '6']
# k
# k
# 2-4
# hnjhpgl
# h
# ['2', '4']
# n
# h
# 3-7
# ttttttrt
# t
# ['3', '7']
# t
# r
# 15-17
# ffffffffffffffhfvf
# f
# ['15', '17']
# h
# v
# 5-7
# nnnnnnnnn
# n
# ['5', '7']
# n
# n
# 10-11
# wkgqggtxbwwkc
# w
# ['10', '11']
# w
# w
# 3-17
# hwqvwqwwwwwzwwvww
# w
# ['3', '17']
# q
# w
# 6-8
# qqqqqrqtq
# q
# ['6', '8']
# r
# t
# 1-3
# nngfpgzcn
# n
# ['1', '3']
# n
# g
# 6-11
# bmzlhhhrrhvjhklpk
# h
# ['6', '11']
# h
# v
# 6-10
# bbbbbbbbbnb
# b
# ['6', '10']
# b
# n
# 5-10
# hgfvlhfdnhwhq
# h
# ['5', '10']
# l
# h
# 2-4
# ggzf
# g
# ['2', '4']
# g
# f
# 2-18
# jjjjjjjjjjjjjjjjjrj
# j
# ['2', '18']
# j
# r
# 15-16
# cckqchlckcnzjcct
# c
# ['15', '16']
# c
# t
# 4-8
# wwskwhjw
# w
# ['4', '8']
# k
# w
# 9-12
# nfnnnntnnkvnn
# n
# ['9', '12']
# n
# n
# 7-10
# rthkcjcdcct
# c
# ['7', '10']
# c
# c
# 11-14
# knnnnnnvnnnznrnxnnnn
# n
# ['11', '14']
# n
# r
# 3-17
# xdxwtxlpwnmqlxvxzh
# x
# ['3', '17']
# x
# z
# 5-6
# pwnflklxwgxlp
# l
# ['5', '6']
# l
# k
# 8-11
# ddqvddxddqk
# d
# ['8', '11']
# d
# k
# 5-10
# xxxxxxxxxxxxxx
# x
# ['5', '10']
# x
# x
# 3-8
# cmtctvlr
# r
# ['3', '8']
# t
# r
# 4-7
# ddcbdddddr
# d
# ['4', '7']
# b
# d
# 6-16
# gggggsgggggggggggggg
# g
# ['6', '16']
# s
# g
# 1-5
# llllzl
# l
# ['1', '5']
# l
# z
# 2-9
# hsfgmxnbhxclv
# c
# ['2', '9']
# s
# h
# 2-9
# hzhhhhchhhhhh
# h
# ['2', '9']
# z
# h
# 1-18
# shhhhhhhhhhhhhhhhhh
# h
# ['1', '18']
# s
# h
# 6-8
# fwzpwhwvqkzw
# w
# ['6', '8']
# h
# v
# 5-12
# wljbgpjldpjjjsslks
# j
# ['5', '12']
# g
# j
# 7-8
# hhhhfhhf
# h
# ['7', '8']
# h
# f
# 3-15
# pppppppppppppppp
# p
# ['3', '15']
# p
# p
# 5-6
# pzppbpvgpppppp
# p
# ['5', '6']
# b
# p
# 11-14
# jfjjjjjjcjzjjjjjj
# j
# ['11', '14']
# z
# j
# 9-11
# hhhhhhhhshh
# h
# ['9', '11']
# s
# h
# 1-6
# hvvvlvvvvv
# v
# ['1', '6']
# h
# v
# 1-4
# dddndd
# d
# ['1', '4']
# d
# n
# 5-6
# crrrcrrr
# r
# ['5', '6']
# c
# r
# 1-6
# tmmmmmm
# m
# ['1', '6']
# t
# m
# 13-15
# bnnngnmnnnnnnntnbnz
# n
# ['13', '15']
# n
# t
# 2-8
# mxxkhfwxhvtr
# x
# ['2', '8']
# x
# x
# 10-12
# jjjmjnjjtxjd
# j
# ['10', '12']
# x
# d
# 3-11
# hvnhhhhhhhhhwbhhqh
# h
# ['3', '11']
# n
# h
# 3-6
# ccccscccrc
# c
# ['3', '6']
# c
# c
# 4-5
# ggllg
# g
# ['4', '5']
# l
# g
# 2-4
# vvvvv
# v
# ['2', '4']
# v
# v
# 6-7
# jmpqnpn
# n
# ['6', '7']
# p
# n
# 1-2
# fwfffnj
# f
# ['1', '2']
# f
# w
# 9-17
# ssssssssbssssssssss
# s
# ['9', '17']
# b
# s
# 12-16
# htxwknmtzlptqxztn
# t
# ['12', '16']
# t
# t
# 12-13
# tlkcxmqhctnsc
# c
# ['12', '13']
# s
# c
# 4-5
# ffffgffffwfffff
# f
# ['4', '5']
# f
# g
# 3-4
# jlvb
# v
# ['3', '4']
# v
# b
# 5-6
# klhdhhv
# h
# ['5', '6']
# h
# h
# 1-3
# nnlnndlnn
# n
# ['1', '3']
# n
# l
# 8-9
# hhhhhhhrthhhhhh
# h
# ['8', '9']
# r
# t
# 6-11
# dddddwddddcdd
# d
# ['6', '11']
# w
# c
# 11-14
# rbrrrrrrrrfrrnrr
# r
# ['11', '14']
# f
# n
# 3-10
# jpkkvnbdmpf
# k
# ['3', '10']
# k
# p
# 6-10
# zzhbhcfhhghhhz
# h
# ['6', '10']
# c
# g
# 5-6
# ttsjtvt
# t
# ['5', '6']
# t
# v
# 14-18
# dtddddmdldsddvghtd
# d
# ['14', '18']
# v
# d
# 7-9
# qqqqqvfqlqqq
# q
# ['7', '9']
# f
# l
# 10-18
# ffffffffffffffffftf
# f
# ['10', '18']
# f
# t
# 10-14
# cckccchcrqccccjz
# c
# ['10', '14']
# q
# c
# 2-4
# srmqqdctnhsrzqqqhscf
# q
# ['2', '4']
# r
# q
# 6-7
# hwzbflz
# z
# ['6', '7']
# l
# z
# 11-14
# dfdgdptdddnddd
# d
# ['11', '14']
# n
# d
# 2-3
# xxzn
# x
# ['2', '3']
# x
# z
# 15-18
# wvqmwhwbhwlkmwwhmqv
# w
# ['15', '18']
# w
# q
# 4-8
# pvfhwhbhhqfqhzl
# h
# ['4', '8']
# h
# h
# 6-13
# wlczflcmlgkjtfwqvl
# l
# ['6', '13']
# l
# t
# 11-12
# rtdckkzzkskpx
# k
# ['11', '12']
# k
# p
# 2-4
# fqfrjff
# f
# ['2', '4']
# q
# r
# 12-16
# vqjjqxqqqmfqqqqx
# q
# ['12', '16']
# q
# x
# 3-4
# mtnnnnnz
# n
# ['3', '4']
# n
# n
# 3-4
# pmsttxst
# s
# ['3', '4']
# s
# t
# 13-15
# xxxxxxxxxxxxxxgzx
# x
# ['13', '15']
# x
# g
# 6-12
# tkcvpmgpzdppdsfv
# p
# ['6', '12']
# m
# p
# 3-4
# jjjsjxj
# j
# ['3', '4']
# j
# s
# 6-9
# hlhhhsqhnhmhhhh
# h
# ['6', '9']
# s
# n
# 3-6
# mmmmmmwmmm
# m
# ['3', '6']
# m
# m
# 1-7
# xkpkzzzgzwtfnzztw
# z
# ['1', '7']
# x
# z
# 2-6
# gzggkggg
# g
# ['2', '6']
# z
# g
# 9-10
# ccccbccccfcccccccccl
# c
# ['9', '10']
# c
# f
# 1-2
# pppppppp
# p
# ['1', '2']
# p
# p
# 11-13
# ggggggggggggzg
# g
# ['11', '13']
# g
# z
# 1-10
# qwzwgwgxww
# w
# ['1', '10']
# q
# w
# 5-6
# wwwwwg
# w
# ['5', '6']
# w
# g
# 4-7
# bghfqzjjnj
# j
# ['4', '7']
# f
# j
# 1-4
# qqqnq
# q
# ['1', '4']
# q
# n
# 4-13
# hwrmnnblzwjpl
# w
# ['4', '13']
# m
# l
# 6-8
# pllllnnll
# l
# ['6', '8']
# n
# l
# 6-8
# nhhhhrwh
# h
# ['6', '8']
# r
# h
# 5-7
# xrjbvkdvw
# v
# ['5', '7']
# v
# d
# 10-17
# xgxxxxxvxxxxzxxwnxhx
# x
# ['10', '17']
# x
# n
# 1-2
# bsbbsfkbhhbdbbcbt
# b
# ['1', '2']
# b
# s
# 1-4
# bnnnnnnnnnnn
# n
# ['1', '4']
# b
# n
# 6-8
# hdllxllj
# l
# ['6', '8']
# l
# j
# 7-12
# tttktztttttgttt
# t
# ['7', '12']
# t
# g
# 3-5
# qvmmnkjcwbjmmcmqccp
# m
# ['3', '5']
# m
# n
# 2-7
# xggqtzqkfckcb
# g
# ['2', '7']
# g
# q
# 9-10
# hwfzhqhhhwxctgpl
# h
# ['9', '10']
# h
# w
# 7-17
# zzzzzzzzzzzzzzzzfz
# z
# ['7', '17']
# z
# f
# 9-12
# zzzzzzzzzzzv
# z
# ['9', '12']
# z
# v
# 2-3
# msmmmmmmmmmm
# m
# ['2', '3']
# s
# m
# 2-3
# qrxkfmgncnrnpd
# r
# ['2', '3']
# r
# x
# 2-3
# dddd
# d
# ['2', '3']
# d
# d
# 12-13
# lllllllllllfx
# l
# ['12', '13']
# f
# x
# 5-10
# vjtsfbkpkps
# b
# ['5', '10']
# f
# p
# 1-4
# gtttttt
# t
# ['1', '4']
# g
# t
# 5-7
# zcdvcjw
# c
# ['5', '7']
# c
# w
# 3-8
# xxxxxnxxxxnx
# x
# ['3', '8']
# x
# x
# 4-12
# jjxdzjrmkqjjzljkdrj
# j
# ['4', '12']
# d
# j
# 15-19
# bprnhsbtpzkxrwwhrvth
# t
# ['15', '19']
# w
# t
# 2-6
# wwwqww
# w
# ['2', '6']
# w
# w
# 5-11
# mwkbmrcgmnkfdp
# k
# ['5', '11']
# m
# k
# 10-13
# zhhhhhhhhhhghhhhh
# h
# ['10', '13']
# h
# h
# 1-5
# bbbbp
# b
# ['1', '5']
# b
# p
# 9-10
# tttvtttstkt
# t
# ['9', '10']
# t
# k
# 1-4
# pwprpp
# p
# ['1', '4']
# p
# r
# 11-13
# fmtddrthmvplhqjbjzjj
# b
# ['11', '13']
# p
# h
# 1-2
# wrzrx
# r
# ['1', '2']
# w
# r
# 1-6
# vxxqsxxrxx
# x
# ['1', '6']
# v
# x
# 7-15
# hsscjphhrqdghhhssst
# h
# ['7', '15']
# h
# h
# 6-7
# hxxzxxjxxxgx
# x
# ['6', '7']
# x
# j
# 2-3
# vgbvv
# v
# ['2', '3']
# g
# b
# 5-8
# bbtgmzcfb
# b
# ['5', '8']
# m
# f
# 4-6
# dllqllbl
# l
# ['4', '6']
# q
# l
# 4-5
# wdhbq
# h
# ['4', '5']
# b
# q
# 10-11
# fnnvwnjklnb
# n
# ['10', '11']
# n
# b
# 11-13
# wlwhdfrxjwgwnwwwtwwh
# w
# ['11', '13']
# g
# n
# 3-5
# dtwwt
# t
# ['3', '5']
# w
# t
# 8-10
# fddjtwqhbbddh
# d
# ['8', '10']
# h
# b
# 15-17
# rfffmgfrtcpffrfjb
# f
# ['15', '17']
# f
# b
# 1-3
# dtbbwbzjlqbb
# b
# ['1', '3']
# d
# b
# 6-7
# kqpvdfr
# f
# ['6', '7']
# f
# r
# 1-3
# kgqggggggggg
# g
# ['1', '3']
# k
# q
# 8-11
# jwbzgqgqcdd
# d
# ['8', '11']
# q
# d
# 5-8
# xxdfsvvxxxss
# x
# ['5', '8']
# s
# x
# 2-3
# fpff
# f
# ['2', '3']
# p
# f
# 4-6
# xrrvrrrrlxrpqrnffw
# r
# ['4', '6']
# v
# r
# 5-9
# bzlrdtvbbltxkn
# b
# ['5', '9']
# d
# b
# 4-9
# ssssssssssssgssssbs
# s
# ['4', '9']
# s
# s
# 2-5
# zzjzdzzzzzbbz
# z
# ['2', '5']
# z
# d
# 5-14
# fssvnkwnfccnsrmb
# n
# ['5', '14']
# n
# r
# 14-16
# vvdkvvvvvnvvvgvvvv
# v
# ['14', '16']
# g
# v
# 15-16
# llllzllllllwlllxll
# l
# ['15', '16']
# l
# x
# 4-7
# ftwffffwvm
# f
# ['4', '7']
# f
# f
# 15-16
# hhhhhhhhhhhfhhbhhh
# h
# ['15', '16']
# b
# h
# 3-5
# ddddsr
# d
# ['3', '5']
# d
# s
# 2-4
# lpvxhnrpxh
# x
# ['2', '4']
# p
# x
# 6-7
# fnnndnc
# n
# ['6', '7']
# n
# c
# 4-9
# fskvrfskf
# f
# ['4', '9']
# v
# f
# 8-11
# mdmmmmcrmnmdlm
# m
# ['8', '11']
# r
# m
# 1-8
# wwwqwwwl
# w
# ['1', '8']
# w
# l
# 4-12
# drwpkvkrzglk
# k
# ['4', '12']
# p
# k
# 8-16
# thjxnbvnsqmqhnjnp
# n
# ['8', '16']
# n
# n
# 13-17
# kkkkkkkqvkkkkmjkkk
# k
# ['13', '17']
# k
# k
# 2-3
# zlgzzzz
# z
# ['2', '3']
# l
# g
# 14-19
# bqqlmqstzqqqfrqddqq
# q
# ['14', '19']
# r
# q
# 2-4
# vttxrq
# t
# ['2', '4']
# t
# x
# 7-10
# hrgsggggggqggg
# g
# ['7', '10']
# g
# g
# 7-8
# pppppppbs
# p
# ['7', '8']
# p
# b
# 7-8
# rtcmttbtttttnt
# t
# ['7', '8']
# b
# t
# 9-10
# kkkkkkkkgkkk
# k
# ['9', '10']
# g
# k
# 13-15
# zzzxkxqzknzqhdhzhrnc
# z
# ['13', '15']
# h
# h
# 3-5
# vvjvvvvvv
# v
# ['3', '5']
# j
# v
# 9-12
# fqfhvsxpfsxfjsvtkfjw
# f
# ['9', '12']
# f
# f
# 13-14
# xswfjdstqrsdnrsn
# s
# ['13', '14']
# n
# r
# 1-7
# zjzzzzw
# z
# ['1', '7']
# z
# w
# 4-5
# dqqnq
# q
# ['4', '5']
# n
# q
# 2-4
# mprnrs
# n
# ['2', '4']
# p
# n
# 16-17
# spssssssssgssssxcsss
# s
# ['16', '17']
# x
# c
# 5-8
# nnlntnnnnnn
# n
# ['5', '8']
# t
# n
# 11-17
# ggggggggggqgnggggggg
# g
# ['11', '17']
# q
# g
# 8-12
# ssssssshsssss
# s
# ['8', '12']
# h
# s
# 3-5
# wwwrw
# w
# ['3', '5']
# w
# w
# 1-4
# dddzdd
# d
# ['1', '4']
# d
# z
# 3-5
# mfccd
# c
# ['3', '5']
# c
# d
# 3-4
# sffxv
# f
# ['3', '4']
# f
# x
# 1-9
# nnsnnnnnt
# n
# ['1', '9']
# n
# t
# 4-9
# ppptpppwpgbppx
# p
# ['4', '9']
# t
# p
# 8-10
# gggggjgggxg
# g
# ['8', '10']
# g
# x
# 10-11
# xwrrrjwjxqr
# r
# ['10', '11']
# q
# r
# 2-3
# xxbdm
# d
# ['2', '3']
# x
# b
# 4-5
# ggggg
# g
# ['4', '5']
# g
# g
# 3-15
# ggqggggggnggggggggc
# g
# ['3', '15']
# q
# g
# 10-13
# scccmcccwcmcmcb
# c
# ['10', '13']
# c
# m
# 3-5
# hhkhhh
# h
# ['3', '5']
# k
# h
# 8-18
# gkfhhjmktrwsrthmhzh
# h
# ['8', '18']
# k
# z
# 3-8
# hlxqbnmk
# x
# ['3', '8']
# x
# k
# 10-16
# qjjjlwctqcbdzhmr
# c
# ['10', '16']
# c
# r
# 1-13
# nbsfcwpxtsxpmqpv
# s
# ['1', '13']
# n
# m
# 11-15
# xxxxxxxxxxxxxxzxx
# x
# ['11', '15']
# x
# z
# 6-7
# wfqcwmw
# w
# ['6', '7']
# m
# w
# 3-10
# wzfrmrfckp
# f
# ['3', '10']
# f
# p
# 3-8
# hlxxxxmmmcvxxdxqb
# x
# ['3', '8']
# x
# m
# 7-18
# dddddddddddddddddld
# d
# ['7', '18']
# d
# l
# 13-17
# fkgfgnftffmfffffsqff
# f
# ['13', '17']
# f
# s
# 6-7
# lllbqnl
# l
# ['6', '7']
# n
# l
# 8-10
# snwpkpwwrcxw
# w
# ['8', '10']
# w
# c
# 1-3
# mpzzkzzzrz
# z
# ['1', '3']
# m
# z
# 5-6
# vmvtgv
# v
# ['5', '6']
# g
# v
# 4-5
# nnngtn
# n
# ['4', '5']
# g
# t
# 6-9
# gffffcfffffff
# f
# ['6', '9']
# c
# f
# 2-4
# ckjxplxj
# x
# ['2', '4']
# k
# x
# 1-2
# tntt
# t
# ['1', '2']
# t
# n
# 14-17
# bbbbbbbzbbbmbbbtdbjb
# b
# ['14', '17']
# b
# d
# 3-6
# rrjmtd
# r
# ['3', '6']
# j
# d
# 4-6
# sssrsst
# s
# ['4', '6']
# r
# s
# 12-15
# vvvvvvvvvvvtvvwv
# v
# ['12', '15']
# t
# w
# 2-3
# wmtgzxfmhl
# g
# ['2', '3']
# m
# t
# 3-11
# frtfxdjhdwx
# t
# ['3', '11']
# t
# x
# 9-12
# gjkkwgcwkbmw
# w
# ['9', '12']
# k
# w
# 7-14
# rrrrrrdsrrrrrrrrrr
# r
# ['7', '14']
# d
# r
# 3-4
# fcck
# c
# ['3', '4']
# c
# k
# 10-11
# lsfsfqflwhf
# f
# ['10', '11']
# h
# f
# 11-12
# cjmfmfffpfhfjnbff
# f
# ['11', '12']
# h
# f
# 2-6
# kskkkkkkk
# k
# ['2', '6']
# s
# k
# 2-9
# qssmsnsshssts
# s
# ['2', '9']
# s
# h
# 1-7
# nhzhzdn
# z
# ['1', '7']
# n
# n
# 2-4
# gglfv
# g
# ['2', '4']
# g
# f
# 3-4
# zkkk
# k
# ['3', '4']
# k
# k
# 10-13
# vvvzvcvrpvvvbvvctvs
# v
# ['10', '13']
# v
# b
# 8-9
# ggzggqggngg
# g
# ['8', '9']
# g
# n
# 2-3
# wwrw
# w
# ['2', '3']
# w
# r
# 6-11
# vvlvvvvvdvbpvvvxsz
# v
# ['6', '11']
# v
# b
# 6-9
# qnnnnvcnnnnnnn
# n
# ['6', '9']
# v
# n
# 7-17
# kkkkkklpkkkkkkkkkkkk
# k
# ['7', '17']
# l
# k
# 2-4
# htxsw
# t
# ['2', '4']
# t
# s
# 4-6
# vplzllvlt
# l
# ['4', '6']
# z
# l
# 1-4
# jxxxx
# x
# ['1', '4']
# j
# x
# 2-3
# llll
# l
# ['2', '3']
# l
# l
# 10-12
# ssssssslstsg
# s
# ['10', '12']
# t
# g
# 8-13
# pkcfwmnmppgwstz
# m
# ['8', '13']
# m
# s
# 1-4
# lllh
# l
# ['1', '4']
# l
# h
# 14-15
# ssssssssssssrcssrs
# s
# ['14', '15']
# c
# s
# 2-9
# vbwpvzcqb
# b
# ['2', '9']
# b
# b
# 6-7
# ssssssdss
# s
# ['6', '7']
# s
# d
# 16-17
# wpvpbpmppvpmpmnlp
# p
# ['16', '17']
# l
# p
# 7-8
# pppppppt
# p
# ['7', '8']
# p
# t
# 3-4
# mmmmmmm
# m
# ['3', '4']
# m
# m
# 1-8
# rrrrrrqbhrr
# r
# ['1', '8']
# r
# b
# 1-6
# crrxbjgtpxxnspk
# x
# ['1', '6']
# c
# j
# 1-8
# wjdmkrmmmhkmqwwcvw
# w
# ['1', '8']
# w
# m
# 6-13
# vvvfvvrvjvvvhvvvvvvv
# v
# ['6', '13']
# v
# h
# 7-8
# jqggxzcgwg
# g
# ['7', '8']
# c
# g
# 1-3
# mwwwwww
# w
# ['1', '3']
# m
# w
# 3-4
# bkff
# f
# ['3', '4']
# f
# f
# 8-10
# ffffffzdff
# f
# ['8', '10']
# d
# f
# 5-7
# vbbbpbbbb
# b
# ['5', '7']
# p
# b
# 6-9
# hhhzhjhhzhh
# h
# ['6', '9']
# j
# z
# 17-19
# rrprrrbrwrqrlrkrjjr
# r
# ['17', '19']
# j
# r
# 5-12
# hbhlhrtjxrlqrhrkldm
# h
# ['5', '12']
# h
# q
# 3-4
# fwdf
# f
# ['3', '4']
# d
# f
# 1-3
# dfff
# f
# ['1', '3']
# d
# f
# 17-18
# lllllllllllllllllll
# l
# ['17', '18']
# l
# l
# 2-10
# wwwwwwwwwzww
# w
# ['2', '10']
# w
# z
# 3-8
# hshthqbqf
# h
# ['3', '8']
# h
# q
# 4-5
# jjxjgj
# j
# ['4', '5']
# j
# g
# 10-11
# khjqtnsstsshhvhls
# s
# ['10', '11']
# s
# s
# 14-15
# jjjjjjjjjjjjjgsjjjj
# j
# ['14', '15']
# g
# s
# 3-5
# mrcjr
# c
# ['3', '5']
# c
# r
# 3-5
# lllnnl
# l
# ['3', '5']
# l
# n
# 2-5
# mttmmkmmm
# m
# ['2', '5']
# t
# m
# 4-20
# mxplkdtwllxmnrzwhsxk
# l
# ['4', '20']
# l
# k
# 15-16
# mnmmmmbmfmmmmmwmmms
# m
# ['15', '16']
# w
# m
# 19-20
# wwwwpkdmwckqcwzhgzjw
# w
# ['19', '20']
# j
# w
# 10-17
# jsvttntthstttztsb
# t
# ['10', '17']
# s
# b
# 7-11
# wmvwwrwgcjh
# w
# ['7', '11']
# w
# h
# 2-3
# lrlrmw
# r
# ['2', '3']
# r
# l
# 4-11
# hpvqmqgdmxrv
# q
# ['4', '11']
# q
# r
# 10-11
# hkhhghshhghhhh
# h
# ['10', '11']
# g
# h
# 3-4
# bqhn
# b
# ['3', '4']
# h
# n
# 8-10
# sssjssczsssss
# s
# ['8', '10']
# z
# s
# 3-7
# pcdjjdccnshcgd
# c
# ['3', '7']
# d
# c
# 2-5
# hbwbnxxct
# b
# ['2', '5']
# b
# n
# 7-9
# ncnjlfntn
# n
# ['7', '9']
# n
# n
# 10-11
# dzrprrrlxrhp
# r
# ['10', '11']
# r
# h
# 1-2
# xlmmgxrxkb
# x
# ['1', '2']
# x
# l
# 4-9
# bbbbbbbbbbbbb
# b
# ['4', '9']
# b
# b
# 2-5
# qgbvvvrpjlvvvv
# v
# ['2', '5']
# g
# v
# 1-5
# vmvvtvvvhv
# v
# ['1', '5']
# v
# t
# 4-8
# wmwpwchvfmz
# w
# ['4', '8']
# p
# v
# 1-5
# lwwwww
# w
# ['1', '5']
# l
# w
# 3-4
# bcbzbt
# b
# ['3', '4']
# b
# z
# 4-5
# frjqrxhvrrkklrx
# r
# ['4', '5']
# q
# r
# 1-4
# hzbj
# j
# ['1', '4']
# h
# j
# 4-5
# bxbdb
# b
# ['4', '5']
# d
# b
# 2-3
# gsggg
# g
# ['2', '3']
# s
# g
# 4-8
# kkmrkpbfl
# k
# ['4', '8']
# r
# f
# 3-4
# rrdrrrr
# r
# ['3', '4']
# d
# r
# 2-4
# zvzd
# v
# ['2', '4']
# v
# d
# 4-5
# zqvvgvxvsvvv
# v
# ['4', '5']
# v
# g
# 17-20
# nwvklgrmkwgjcflhgnbv
# g
# ['17', '20']
# g
# v
# 2-5
# qqqqjqqqqqqqqqq
# q
# ['2', '5']
# q
# j
# 8-14
# zhhldhswhhhlhhhb
# h
# ['8', '14']
# w
# h
# 2-3
# ccbc
# c
# ['2', '3']
# c
# b
# 2-17
# fhhghdhhhhhfgdhlvh
# h
# ['2', '17']
# h
# v
# 5-8
# wmtwwwfwgwgw
# w
# ['5', '8']
# w
# w
# 4-5
# gbbhk
# b
# ['4', '5']
# h
# k
# 15-17
# mfqbdfzffffdtpffk
# f
# ['15', '17']
# f
# k
# 2-4
# wgzg
# s
# ['2', '4']
# g
# g
# 16-19
# nnnnnnnnnnnnnnnfnnmn
# n
# ['16', '19']
# f
# m
# 11-13
# vccvmxmfhmvlrmw
# v
# ['11', '13']
# v
# r
# 9-13
# pppppppplppppp
# p
# ['9', '13']
# l
# p
# 3-4
# mvlvvv
# v
# ['3', '4']
# l
# v
# 1-9
# tttttttcnttttxt
# t
# ['1', '9']
# t
# n
# 1-4
# nngn
# n
# ['1', '4']
# n
# n
# 13-17
# qqqgqqqqqqqqqqqqxq
# q
# ['13', '17']
# q
# x
# 10-16
# zzzzzbztzvzzzzlzzzzz
# z
# ['10', '16']
# v
# z
# 5-10
# rrrrjrrrrrr
# r
# ['5', '10']
# j
# r
# 4-10
# mtrwzshzcz
# w
# ['4', '10']
# w
# z
# 10-14
# zsfjzwgvbzmtzwb
# z
# ['10', '14']
# z
# w
# 1-6
# hbbbbbbbb
# b
# ['1', '6']
# h
# b
# 11-13
# hhhhhhhhhhhht
# h
# ['11', '13']
# h
# t
# 2-6
# ghsfzhk
# h
# ['2', '6']
# h
# h
# 5-6
# spncxdzsnx
# x
# ['5', '6']
# x
# d
# 5-9
# jxwwdqxpj
# j
# ['5', '9']
# d
# j
# 1-3
# nnndnn
# n
# ['1', '3']
# n
# n
# 1-13
# tqppjpppppppsqppp
# p
# ['1', '13']
# t
# s
# 7-9
# hhhhhhchqhs
# h
# ['7', '9']
# c
# q
# 3-4
# bfftjfxfffmflmtn
# f
# ['3', '4']
# f
# t
# 11-12
# mmmmmmmmmmhmmmmmm
# m
# ['11', '12']
# h
# m
# 1-2
# rwvctzp
# r
# ['1', '2']
# r
# w
# 2-6
# hvswzjtg
# g
# ['2', '6']
# v
# j
# 4-13
# jhxsvwsrhhnmmqx
# s
# ['4', '13']
# s
# m
# 5-6
# jfjjjjq
# j
# ['5', '6']
# j
# j
# 1-3
# vkkk
# k
# ['1', '3']
# v
# k
# 3-7
# ctcccckccjvcccccccc
# c
# ['3', '7']
# c
# k
# 12-14
# wwwwwwwwwwpbwvww
# w
# ['12', '14']
# b
# v
# 14-15
# bbbbbbbbbbbbbbpbb
# b
# ['14', '15']
# b
# p
# 5-10
# gdfmfzfxggggkcvn
# g
# ['5', '10']
# f
# g
# 11-12
# hhhhhshhhhdh
# h
# ['11', '12']
# d
# h
# 3-8
# vvvvvvvzv
# v
# ['3', '8']
# v
# z
# 9-11
# kbzbbfbbggshllgls
# b
# ['9', '11']
# g
# s
# 3-5
# rwkkqkbkcvks
# k
# ['3', '5']
# k
# q
# 1-5
# bbhbbbx
# b
# ['1', '5']
# b
# b
# 1-13
# pfffffffffvflffff
# f
# ['1', '13']
# p
# l
# 2-4
# qqqmh
# q
# ['2', '4']
# q
# m
# 6-8
# vjfbdbblj
# b
# ['6', '8']
# b
# l
# 4-7
# xxxxxxdxxxxxx
# x
# ['4', '7']
# x
# d
# 1-9
# lxmvxxxxxxxxj
# x
# ['1', '9']
# l
# x
# 5-8
# scczssdljc
# s
# ['5', '8']
# s
# l
# 3-5
# qvvdw
# v
# ['3', '5']
# v
# w
# 5-10
# mmmbcmzhzms
# m
# ['5', '10']
# c
# m
# 2-9
# rbrrrrrrmrr
# r
# ['2', '9']
# b
# m
# 6-7
# xxxxkpqqx
# x
# ['6', '7']
# p
# q
# 16-18
# rvbbbbjcnpbbzbbbbpx
# b
# ['16', '18']
# b
# p
# 6-7
# jpqdjjjrc
# g
# ['6', '7']
# j
# j
# 2-4
# nzjm
# m
# ['2', '4']
# z
# m
# 2-10
# vvvjsxvjvvvp
# v
# ['2', '10']
# v
# v
# 2-8
# qxsbfjtbr
# b
# ['2', '8']
# x
# b
# 10-18
# gbrdpfccpcgdktgxrtrr
# c
# ['10', '18']
# c
# t
# 1-8
# mmmmmmmq
# m
# ['1', '8']
# m
# q
# 2-3
# wktw
# w
# ['2', '3']
# k
# t
# 2-7
# mmmmmmdm
# m
# ['2', '7']
# m
# d
# 1-8
# ggggggghg
# g
# ['1', '8']
# g
# h
# 3-4
# scpsqm
# s
# ['3', '4']
# p
# s
# 11-15
# ppphhlmkgmkdqvfpkk
# k
# ['11', '15']
# k
# f
# 8-9
# pcnrjwdxrcrtqh
# r
# ['8', '9']
# x
# r
# 6-8
# lqnnnwnnbn
# n
# ['6', '8']
# w
# n
# 8-9
# bmljwjjxz
# j
# ['8', '9']
# x
# z
# 3-7
# wxpxpvr
# p
# ['3', '7']
# p
# r
# 5-14
# knbnnnnhtnnzvnknn
# n
# ['5', '14']
# n
# n
# 2-7
# lsmkfrhpsdnpf
# l
# ['2', '7']
# s
# h
# 2-3
# ssmss
# s
# ['2', '3']
# s
# m
# 12-13
# nnnnnmnnjnnngnn
# n
# ['12', '13']
# n
# g
# 1-5
# vrvcvvvv
# v
# ['1', '5']
# v
# v
# 11-16
# qqqqjjzqzqqqnqqd
# q
# ['11', '16']
# q
# d
# 8-10
# xjjpcvfvltwllrvvbtd
# v
# ['8', '10']
# v
# t
# 1-17
# qqqqzqqqqxqqqqqqp
# q
# ['1', '17']
# q
# p
# 6-15
# wvrlqvvqdrkgkkk
# k
# ['6', '15']
# v
# k
# 2-4
# sgrh
# s
# ['2', '4']
# g
# h
# 5-15
# qxdmzmqmwhpbjjbhs
# b
# ['5', '15']
# z
# b
# 4-5
# wzzdf
# z
# ['4', '5']
# d
# f
# 4-8
# vzwmzwzqr
# z
# ['4', '8']
# m
# q
# 2-5
# xsxxvx
# x
# ['2', '5']
# s
# v
# 14-18
# tttttttttttttckttttt
# t
# ['14', '18']
# c
# t
# 9-10
# rrrrrrrbbr
# r
# ['9', '10']
# b
# r
# 6-7
# vtvnnhvvqx
# v
# ['6', '7']
# h
# v
# 12-13
# swgggltgggjpggdkpc
# g
# ['12', '13']
# p
# g
# 9-16
# xcpgjqrxfdldqzwj
# f
# ['9', '16']
# f
# j
# 2-11
# dddddddbddddd
# d
# ['2', '11']
# d
# d
# 8-10
# mmjmmmmmmdml
# m
# ['8', '10']
# m
# d
# 6-13
# pqmbcnmmqsmjmm
# m
# ['6', '13']
# n
# m
# 5-6
# wgdrsdd
# d
# ['5', '6']
# s
# d
# 10-13
# hxrrcrbrrsqrrrrrrs
# r
# ['10', '13']
# s
# r
# 2-3
# gddd
# d
# ['2', '3']
# d
# d
# 15-19
# qqqqqqqqqqqqqqkqqqjq
# q
# ['15', '19']
# k
# j
# 16-17
# pppqpppppppppppnbpp
# p
# ['16', '17']
# n
# b
# 1-6
# rppngpnppppjpp
# p
# ['1', '6']
# r
# p
# 2-3
# vvvvd
# v
# ['2', '3']
# v
# v
# 5-6
# pccccxccc
# c
# ['5', '6']
# c
# x
# 3-14
# ddfddddddddddddddddd
# d
# ['3', '14']
# f
# d
# 13-14
# ttttjttdhwtqthq
# t
# ['13', '14']
# t
# h
# 7-8
# sddddddvd
# d
# ['7', '8']
# d
# v
# 12-16
# jgzfffhpzffffffr
# f
# ['12', '16']
# f
# r
# 4-6
# jjmjjj
# j
# ['4', '6']
# j
# j
# 2-5
# gxpvhhb
# h
# ['2', '5']
# x
# h
# 1-14
# mmmmmzmmmmmrmpxz
# m
# ['1', '14']
# m
# p
# 5-6
# gxctgm
# g
# ['5', '6']
# g
# m
# 4-6
# wbbfbtgl
# b
# ['4', '6']
# f
# t
# 3-7
# bbskxwqnkbbdbbbb
# b
# ['3', '7']
# s
# q
# 5-7
# rrrrvmkrrrrrr
# r
# ['5', '7']
# v
# k
# 5-9
# sssskssssss
# s
# ['5', '9']
# k
# s
# 10-15
# pnrtwkwbwwgwkwrm
# w
# ['10', '15']
# w
# r
# 8-18
# cjrxqxrllccfcsvccct
# c
# ['8', '18']
# l
# c
# 14-17
# vgslbvvnvvvvspvtv
# v
# ['14', '17']
# p
# v
# 3-4
# hkrq
# q
# ['3', '4']
# r
# q
# 11-15
# rrrrrrrrrrrrrrl
# r
# ['11', '15']
# r
# l
# 1-17
# czzzzzzzzzzzzzzzzz
# z
# ['1', '17']
# c
# z
# 3-4
# pppfpp
# p
# ['3', '4']
# p
# f
# 8-11
# hwswwwwwwwgwww
# w
# ['8', '11']
# w
# g
# 18-19
# sssssbssfsssssstwsz
# s
# ['18', '19']
# s
# z
# 6-8
# pfpppjppp
# p
# ['6', '8']
# j
# p
# 4-6
# wjrkrt
# w
# ['4', '6']
# k
# t
# 3-5
# tthtrctt
# t
# ['3', '5']
# h
# r
# 3-7
# fxvpwwttvg
# t
# ['3', '7']
# v
# t
# 6-7
# lllmlfl
# l
# ['6', '7']
# f
# l
# 9-10
# hcxxccccjkccc
# c
# ['9', '10']
# j
# k
# 7-11
# pdndddnkdqdqmzdb
# d
# ['7', '11']
# n
# d
# 7-15
# wwwwlwcwwwwxbwww
# w
# ['7', '15']
# c
# w
# 2-3
# ffgjfk
# f
# ['2', '3']
# f
# g
# 8-12
# qjmwphbhbdbrz
# h
# ['8', '12']
# h
# r
# 2-3
# ssxshs
# s
# ['2', '3']
# s
# x
# 6-7
# dddddrjqtdd
# d
# ['6', '7']
# r
# j
# 4-9
# sbhstssxqsscsssf
# s
# ['4', '9']
# s
# q
# 2-4
# fgvfhnnlwlbdcbzcgrp
# f
# ['2', '4']
# g
# f
# 7-10
# ghbnnnnbnngnsfnnbn
# n
# ['7', '10']
# n
# n
# 1-12
# dttctttttttctqt
# t
# ['1', '12']
# d
# c
# 5-11
# bfbbhbbbbbmtb
# b
# ['5', '11']
# h
# m
# 2-12
# pbmtsjfftkmqqgdfr
# g
# ['2', '12']
# b
# q
# 16-17
# mmmxmmmmhmdmhmsmd
# m
# ['16', '17']
# m
# d
# 1-15
# ccccccccccccccccc
# c
# ['1', '15']
# c
# c
# 1-2
# ctcc
# c
# ['1', '2']
# c
# t
# 1-15
# lmmmmmmmmmmmmmmm
# m
# ['1', '15']
# l
# m
# 6-7
# sdkksds
# s
# ['6', '7']
# d
# s
# 5-6
# cnxjsx
# x
# ['5', '6']
# s
# x
# 3-5
# tptntbnbqqc
# t
# ['3', '5']
# t
# t
# 18-19
# fvfvrlvdlmrjfprbrxr
# r
# ['18', '19']
# x
# r
# 7-12
# wwwwwwrwwwwwwwd
# w
# ['7', '12']
# r
# w
# 15-18
# jjjjjjjjjjjjjjpjjjj
# j
# ['15', '18']
# p
# j
# 3-5
# sldsllqd
# l
# ['3', '5']
# d
# l
# 13-14
# ccccccccccxcch
# c
# ['13', '14']
# c
# h
# 6-10
# mmmfmmcjsqmm
# m
# ['6', '10']
# m
# q
# 5-9
# ffffffffxfff
# f
# ['5', '9']
# f
# x
# 9-13
# llzllkgltfwlqvrllzz
# l
# ['9', '13']
# t
# q
# 7-9
# vhzbhhhhw
# h
# ['7', '9']
# h
# w
# 8-11
# bkbbbpqzjpbhbbbbx
# b
# ['8', '11']
# z
# b
# 13-14
# rrrrrrrrrkrrrz
# r
# ['13', '14']
# r
# z
# 11-12
# qdqqqqqqqqkq
# q
# ['11', '12']
# k
# q
# 1-3
# jqhttpttlr
# t
# ['1', '3']
# j
# h
# 9-10
# tnxtsfxwhx
# x
# ['9', '10']
# h
# x
# 3-4
# kkkkkvhpxqbk
# k
# ['3', '4']
# k
# k
# 10-11
# cclqkjkcchc
# c
# ['10', '11']
# h
# c
# 3-12
# tttttttftttdtfttt
# t
# ['3', '12']
# t
# d
# 8-10
# cfccvckxcm
# c
# ['8', '10']
# x
# m
# 2-18
# tgtttttttttttttttttt
# t
# ['2', '18']
# g
# t
# 12-18
# xrjjrmvgrgwwdrbjtq
# r
# ['12', '18']
# w
# q
# 11-12
# mcmmmmmmmmmsmmmmm
# m
# ['11', '12']
# m
# s
# 3-5
# jbwpjdwrppl
# j
# ['3', '5']
# w
# j
# 6-9
# ddddbvqdsddd
# d
# ['6', '9']
# v
# s
# 1-2
# pzzcz
# z
# ['1', '2']
# p
# z
# 4-6
# xvqbtg
# b
# ['4', '6']
# b
# g
# 7-10
# wsbngzzxrbwgj
# j
# ['7', '10']
# z
# b
# 1-5
# pdddldvd
# d
# ['1', '5']
# p
# l
# 2-3
# wpmqk
# s
# ['2', '3']
# p
# m
# 3-8
# pwpppdpw
# p
# ['3', '8']
# p
# w
# 1-12
# qrcqbjrpjtrxhdbq
# q
# ['1', '12']
# q
# x
# 5-6
# bmptbn
# b
# ['5', '6']
# b
# n
# 16-18
# mmmzmmmmmmlmmmmmqx
# m
# ['16', '18']
# m
# x
# 4-17
# sssrssssssssssssss
# s
# ['4', '17']
# r
# s
# 8-13
# xxxxxxxxxxxxqxxx
# x
# ['8', '13']
# x
# q
# 3-4
# wsvw
# w
# ['3', '4']
# v
# w
# 4-6
# bxtgvb
# x
# ['4', '6']
# g
# b
# 8-10
# tttttnttth
# t
# ['8', '10']
# t
# h
# 1-4
# xmmswnwvvsmm
# m
# ['1', '4']
# x
# s
# 2-7
# mmmmmmmx
# m
# ['2', '7']
# m
# m
# 3-14
# klpcktvzbvnjjcf
# c
# ['3', '14']
# p
# c
# 1-6
# pppppk
# p
# ['1', '6']
# p
# k
# 3-4
# ddjd
# d
# ['3', '4']
# j
# d
# 2-3
# wwxwwdwbwwww
# w
# ['2', '3']
# w
# x
# 2-5
# qtbht
# t
# ['2', '5']
# t
# t
# 4-6
# ltlhhn
# h
# ['4', '6']
# h
# n
# 5-16
# ssskmbbslssswsssx
# s
# ['5', '16']
# m
# s
# 2-8
# lkvvvrvvvvvvvvvpvmvv
# v
# ['2', '8']
# k
# v
# 2-3
# dzdd
# d
# ['2', '3']
# z
# d
# 7-10
# gqgmgsggpggg
# g
# ['7', '10']
# g
# g
# 10-12
# gjgggggggkhgggg
# g
# ['10', '12']
# k
# g
# 4-5
# hqkvm
# z
# ['4', '5']
# v
# m
# 2-11
# ntvvvpvvvvvvvvvvv
# v
# ['2', '11']
# t
# v
# 3-4
# kbddd
# d
# ['3', '4']
# d
# d
# 3-4
# qqqq
# q
# ['3', '4']
# q
# q
# 1-4
# wwnw
# w
# ['1', '4']
# w
# w
# 4-5
# thmmg
# p
# ['4', '5']
# m
# g
# 2-5
# mpdstn
# n
# ['2', '5']
# p
# t
# 9-10
# svhvlhqmls
# l
# ['9', '10']
# l
# s
# 5-6
# qhxxxx
# x
# ['5', '6']
# x
# x
# 11-20
# rgddnnddkjdnccrrxdsw
# d
# ['11', '20']
# d
# w
# 2-3
# jkxk
# k
# ['2', '3']
# k
# x
# 5-7
# lqlskzphbknwnzznwzj
# z
# ['5', '7']
# k
# p
# 13-14
# ppcpkptppjkppdkppppp
# p
# ['13', '14']
# p
# d
# 14-17
# kkkkkkkkkkkkkkkkw
# k
# ['14', '17']
# k
# w
# 2-3
# lzlll
# l
# ['2', '3']
# z
# l
# 2-8
# pppppppppppppppppppp
# p
# ['2', '8']
# p
# p
# 4-10
# wwcwwjtwwnwbklc
# w
# ['4', '10']
# w
# n
# 10-11
# mrrrrrrrrzrrrrr
# r
# ['10', '11']
# z
# r
# 4-11
# gnvpjmztlftj
# t
# ['4', '11']
# p
# t
# 11-12
# ttttttttttxt
# t
# ['11', '12']
# x
# t
# 3-6
# ckdtgxxtz
# x
# ['3', '6']
# d
# x
# 2-3
# lklq
# l
# ['2', '3']
# k
# l
# 1-11
# lccgcccczcccccxbccc
# c
# ['1', '11']
# l
# c
# 7-8
# nnnnnnmrn
# n
# ['7', '8']
# m
# r
# 3-6
# nglpdw
# w
# ['3', '6']
# l
# w
# 7-14
# llllllllllllllll
# l
# ['7', '14']
# l
# l
# 11-15
# xxxxmxxbxnwrhxx
# x
# ['11', '15']
# w
# x
# 2-5
# stwpllglbjg
# l
# ['2', '5']
# t
# l
# 4-5
# nmhnb
# c
# ['4', '5']
# n
# b
# 4-6
# lllglfll
# l
# ['4', '6']
# g
# f
# 6-10
# lgjbjwqbrb
# b
# ['6', '10']
# w
# b
# 5-6
# zzczzl
# z
# ['5', '6']
# z
# l
# 1-6
# bfffftftfff
# f
# ['1', '6']
# b
# t
# 3-5
# hhhhh
# h
# ['3', '5']
# h
# h
# 5-12
# nhhshjwmhgsnw
# h
# ['5', '12']
# h
# n
# 14-15
# wwwwwwwwwwwwwlw
# w
# ['14', '15']
# l
# w
# 2-4
# xjwsjkgdr
# j
# ['2', '4']
# j
# s
# 16-18
# dqjtzgdzjjvkppmjjb
# j
# ['16', '18']
# j
# b
# 5-6
# wgkqztqw
# q
# ['5', '6']
# z
# t
# 1-5
# fmmmmmm
# m
# ['1', '5']
# f
# m
# 10-19
# ddvndsfgddbndlrddqd
# d
# ['10', '19']
# d
# d
# 9-14
# jvvvvvvvwpvvvvgvvv
# v
# ['9', '14']
# w
# v
# 2-14
# fmzmsbkfcjfqxj
# m
# ['2', '14']
# m
# j
# 3-12
# jjjjjjjjjjjjjjjj
# j
# ['3', '12']
# j
# j
# 1-2
# gqgg
# g
# ['1', '2']
# g
# q
# 15-19
# pbngdnwnnnnnvnnnnjg
# n
# ['15', '19']
# n
# g
# 10-12
# vjjjjjjjjfjjj
# j
# ['10', '12']
# f
# j
# 13-16
# xxxxpxxxxxxxqtxxxx
# x
# ['13', '16']
# q
# x
# 3-7
# wdsklkk
# k
# ['3', '7']
# s
# k
# 7-10
# jmmmjmpmmmd
# m
# ['7', '10']
# p
# m
# 5-7
# jjjskgj
# j
# ['5', '7']
# k
# j
# 10-16
# qfccpzlccccdckdc
# c
# ['10', '16']
# c
# c
# 16-17
# lllqlqhllcljqlwlll
# l
# ['16', '17']
# l
# l
# 9-12
# flvjbtxnwjzj
# j
# ['9', '12']
# w
# j
# 4-18
# vvvvvvvvvvvvvvvvvvv
# v
# ['4', '18']
# v
# v
# 5-9
# tnnxxgxmvdqxxxzgxh
# x
# ['5', '9']
# x
# v
# 3-7
# clmdbmc
# c
# ['3', '7']
# m
# c
# 7-14
# ssqssssssssssnss
# s
# ['7', '14']
# s
# n
# 3-5
# ddqddd
# d
# ['3', '5']
# q
# d
# 1-2
# ptpp
# p
# ['1', '2']
# p
# t
# 4-10
# gggggggggdggg
# g
# ['4', '10']
# g
# d
# 2-3
# mqmcgmd
# m
# ['2', '3']
# q
# m
# 1-2
# wwwwww
# w
# ['1', '2']
# w
# w
# 2-7
# jjjjjkdmtbs
# j
# ['2', '7']
# j
# d
# 3-7
# qxsqqfqqdnjdjq
# q
# ['3', '7']
# s
# q
# 2-11
# cccmqccccckccccc
# c
# ['2', '11']
# c
# k
# 2-8
# ccccccccvc
# c
# ['2', '8']
# c
# c
# 1-2
# qqxjq
# q
# ['1', '2']
# q
# q
# 5-8
# mtmmkmsmzjdckb
# m
# ['5', '8']
# k
# m
# 10-12
# kthrphrfqqfr
# r
# ['10', '12']
# q
# r
# 3-8
# gkkddfqwsffrp
# k
# ['3', '8']
# k
# w
# 9-10
# kppppjcspkmpppppk
# p
# ['9', '10']
# p
# k
# 6-9
# rghxzzlhx
# l
# ['6', '9']
# z
# x
# 3-4
# wmvw
# m
# ['3', '4']
# v
# w
# 3-7
# mmwwdrx
# w
# ['3', '7']
# w
# x
# 8-9
# blhsztwft
# t
# ['8', '9']
# f
# t
# 4-9
# rnnnnpnxn
# n
# ['4', '9']
# n
# n
# 8-18
# vvvjvvvvbhvqdcfrtbxj
# v
# ['8', '18']
# v
# b
# 2-3
# dtdfhw
# t
# ['2', '3']
# t
# d
# 6-15
# mmmmmxmmmmmmmmmmm
# m
# ['6', '15']
# x
# m
# 11-17
# bpchqrpzxhcbcqmvh
# c
# ['11', '17']
# c
# h
# 8-12
# lqldlplmdjpldldfjn
# l
# ['8', '12']
# m
# l
# 5-6
# vvvtlv
# v
# ['5', '6']
# l
# v
# 3-6
# rnrgwqdbtrdc
# r
# ['3', '6']
# r
# q
# 3-6
# fxqldttzq
# t
# ['3', '6']
# q
# t
# 4-5
# nnzknnbcrbz
# n
# ['4', '5']
# k
# n
# 6-7
# npwmnrs
# n
# ['6', '7']
# r
# s
# 4-7
# rnrkqqbhrmrrrrtr
# r
# ['4', '7']
# k
# b
# 2-7
# mbmmgmmmmmmmmmmm
# m
# ['2', '7']
# b
# m
# 3-8
# wwrwwwwwwvww
# w
# ['3', '8']
# r
# w
# 1-2
# ttqrttmptccxwkztjtsg
# t
# ['1', '2']
# t
# t
# 2-4
# ssscs
# s
# ['2', '4']
# s
# c
# 1-5
# bcncbccc
# c
# ['1', '5']
# b
# b
# 6-11
# ssrvssrttsb
# s
# ['6', '11']
# s
# b
# 1-8
# kczcvcwl
# z
# ['1', '8']
# k
# l
# 7-8
# ttttttqt
# t
# ['7', '8']
# q
# t
# 1-4
# wdddd
# d
# ['1', '4']
# w
# d
# 9-15
# ffffffffffffffffff
# f
# ['9', '15']
# f
# f
# 6-7
# vvvvvkdgvp
# v
# ['6', '7']
# k
# d
# 6-8
# ttsttttp
# t
# ['6', '8']
# t
# p
# 1-3
# qsjssns
# s
# ['1', '3']
# q
# j
# 3-5
# xrrnrktrhjqlqlrhrlkr
# r
# ['3', '5']
# r
# r
# 3-8
# nnnnnnbx
# n
# ['3', '8']
# n
# x
# 1-3
# mqqqqqqv
# q
# ['1', '3']
# m
# q
# 4-6
# tttldvtt
# t
# ['4', '6']
# l
# v
# 16-19
# pmzzdmmnzrzhmfvmkms
# m
# ['16', '19']
# m
# s
# 2-4
# sxmth
# t
# ['2', '4']
# x
# t
# 3-13
# bbsbbbbxbbbbkbbbbb
# b
# ['3', '13']
# s
# k
# 5-7
# kkjrnnn
# n
# ['5', '7']
# n
# n
# 1-3
# bcbbb
# b
# ['1', '3']
# b
# b
# 6-8
# wwwwwwwbwwkw
# w
# ['6', '8']
# w
# b
# 3-11
# xccmsqcsvwv
# c
# ['3', '11']
# c
# v
# 7-10
# clhtfgmnfnpvwvzv
# n
# ['7', '10']
# m
# n
# 6-7
# vvvvvdvvzv
# v
# ['6', '7']
# d
# v
# 1-16
# ssckbjfgcfwgppck
# k
# ['1', '16']
# s
# k
# 10-12
# rrrrrrrrrfrrrr
# r
# ['10', '12']
# f
# r
# 17-19
# rrrrrrrrrrrrrrrrbrlr
# r
# ['17', '19']
# b
# l
# 2-8
# qlhgldtlbzzvt
# l
# ['2', '8']
# l
# l
# 11-12
# mcbpvhmtfgsh
# h
# ['11', '12']
# s
# h
# 3-7
# gvvvkkvkvvj
# v
# ['3', '7']
# v
# v
# 1-9
# ddddddddq
# d
# ['1', '9']
# d
# q
# 4-5
# vdlfll
# v
# ['4', '5']
# f
# l
# 8-9
# xjzptzzzr
# z
# ['8', '9']
# z
# r
# 19-20
# nlnnnnnznnnnnnnnsndk
# n
# ['19', '20']
# d
# k
# 7-9
# rrrrrrrrsrrr
# r
# ['7', '9']
# r
# s
# 5-6
# ddddwdd
# d
# ['5', '6']
# w
# d
# 18-19
# fjjjfjljwhjjjbjjjgr
# j
# ['18', '19']
# g
# r
# 3-7
# ddddtdddddddddd
# d
# ['3', '7']
# d
# d
# 2-4
# pbmp
# p
# ['2', '4']
# b
# p
# 6-7
# trrhwrb
# r
# ['6', '7']
# r
# b
# 6-12
# zppllllmpfwkvnh
# l
# ['6', '12']
# l
# k
# 11-14
# llcvllllllllsl
# l
# ['11', '14']
# l
# l
# 1-4
# kkkjkk
# k
# ['1', '4']
# k
# j
# 2-6
# mqmmmf
# m
# ['2', '6']
# q
# f
# 3-10
# bxbbbbbbbntbdblb
# b
# ['3', '10']
# b
# n
# 12-13
# nhplrlncpxzbh
# h
# ['12', '13']
# b
# h
# 17-19
# ssssssssssssssssfss
# s
# ['17', '19']
# f
# s
# 3-4
# kfxx
# x
# ['3', '4']
# x
# x
# 7-9
# llllllrlqwl
# l
# ['7', '9']
# r
# q
# 2-4
# zwrqqhrbx
# q
# ['2', '4']
# w
# q
# 7-11
# qpqwgbgcgkzbgn
# g
# ['7', '11']
# g
# z
# 6-7
# wwwwwglwwwww
# w
# ['6', '7']
# g
# l
# 5-6
# dbbbfb
# b
# ['5', '6']
# f
# b
# 2-4
# ckpp
# p
# ['2', '4']
# k
# p
# 2-14
# bxtgfvzxcbrqkxjqk
# x
# ['2', '14']
# x
# x
# 2-4
# gpfx
# x
# ['2', '4']
# p
# x
# 2-5
# pbglg
# g
# ['2', '5']
# b
# g
# 7-11
# wwrjjbjtpjwzhgsqj
# w
# ['7', '11']
# j
# w
# 1-3
# xgmrxcqxbpfxxxbxxxf
# x
# ['1', '3']
# x
# m
# 7-8
# qwrvqvqhs
# r
# ['7', '8']
# q
# h
# 4-8
# dtjtlhgvrxjb
# t
# ['4', '8']
# t
# v
# 13-14
# nvsmqzmclhwpdc
# c
# ['13', '14']
# d
# c
# 7-10
# xbkspdlbbbbbnfnb
# b
# ['7', '10']
# l
# b
# 16-17
# jjjfjjjjjjjjjjjjl
# j
# ['16', '17']
# j
# l
# 3-4
# snnrp
# n
# ['3', '4']
# n
# r
# 11-15
# rrrrrrrrrrrrrrrr
# r
# ['11', '15']
# r
# r
# 8-10
# mcgnngfnrjpkxdmjnnx
# n
# ['8', '10']
# n
# j
# 9-16
# xzxxxxxxxxxxxxxdxxxx
# x
# ['9', '16']
# x
# d
# 9-10
# xxxxxxxdfx
# x
# ['9', '10']
# f
# x
# 1-11
# gxxxxxxxxxmxxxx
# x
# ['1', '11']
# g
# m
# 9-11
# ssjssssgksfs
# s
# ['9', '11']
# k
# f
# 5-6
# pdrmrgrwrlxr
# r
# ['5', '6']
# r
# g
# 3-6
# fwfdsfzddj
# f
# ['3', '6']
# f
# f
# 7-8
# ccccccgc
# c
# ['7', '8']
# g
# c
# 3-8
# wttlmpdkfkf
# t
# ['3', '8']
# t
# k
# 6-7
# xsvmsds
# s
# ['6', '7']
# d
# s
# 6-7
# jbncncnn
# n
# ['6', '7']
# c
# n

# %%
# results2
# Out:
# [True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True]

# %%
sum(results2)
# Out:
# 690
